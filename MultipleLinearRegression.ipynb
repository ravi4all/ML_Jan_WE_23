# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('NIFTY 50_Data.csv')

# %%
df.shape
# Out:
# (3227, 5)

# %%
df.head()
# Out:
#           Date      Open      High       Low     Close
# 0  24 Feb 2023  17591.35  17599.75  17421.80  17465.80
# 1  23 Feb 2023  17574.65  17620.05  17455.40  17511.25
# 2  22 Feb 2023  17755.35  17772.50  17529.45  17554.30
# 3  21 Feb 2023  17905.80  17924.90  17800.30  17826.70
# 4  20 Feb 2023  17965.55  18004.35  17818.40  17844.60

# %%
df['Date'][0]
# Out:
# '24 Feb 2023'

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'][0]
# Out:
# Timestamp('2023-02-24 00:00:00')

# %%
df['Close'][0]
# Out:
# 17465.8

# %%
plt.plot(df['Date'], df['High'])
plt.show()

# %%
df.sort_index(ascending=False,inplace=True)

# %%
df.head()
# Out:
#            Date     Open     High      Low   Close
# 3226 2010-02-26  4858.50  4992.00  4858.45  4922.3
# 3225 2010-03-02  4935.60  5029.45  4935.35  5017.0
# 3224 2010-03-03  5015.80  5093.25  5015.10  5088.1
# 3223 2010-03-04  5096.95  5096.95  5049.00  5080.2
# 3222 2010-03-05  5080.55  5118.65  5068.05  5088.7

# %%
df.tail()
# Out:
#         Date      Open      High       Low     Close
# 4 2023-02-20  17965.55  18004.35  17818.40  17844.60
# 3 2023-02-21  17905.80  17924.90  17800.30  17826.70
# 2 2023-02-22  17755.35  17772.50  17529.45  17554.30
# 1 2023-02-23  17574.65  17620.05  17455.40  17511.25
# 0 2023-02-24  17591.35  17599.75  17421.80  17465.80

# %%
X = df.iloc[:,1:-1].values
y = df.iloc[:,-1].values

# %%
X[0]
# Out:
# array([4858.5 , 4992.  , 4858.45])

# %%
y[0]
# Out:
# 4922.3

# %%
regression = LinearRegression()
regresion.fit(X,y)
# Out:
# LinearRegression()

# %%
predictions = regression.predict(X)

# %%
predictions[0]
# Out:
# 4975.996684964688

# %%
mean_absolute_error(y, predictions)
# Out:
# 21.891847799049376

# %%
plt.plot(df['Date'], df['Close'])
plt.plot(df['Date'], predictions, 'red')
plt.show()

# %%
# test_X = np.array([[17465.80,17655.75,17460.80]])
test_X = np.array([[17465.80,17655.75,15460.80]])

# %%
regression.predict(test_X)
# Out:
# array([16134.88015041])

# %%
r2_score(y, predictions)
# Out:
# 0.9999226039703487
